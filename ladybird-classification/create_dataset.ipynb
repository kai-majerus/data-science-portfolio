# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# Load multimedia.txt
multimedia_df = pd.read_csv('full_dataset/multimedia.txt', sep='\t')

# Load occurrence.txt
occurrence_df = pd.read_csv('full_dataset/occurrence.txt', sep='\t', low_memory=False)

# %%
multimedia_df.head(2)
# Out:
#        gbifID        type      format  \
# 0  1038336887  StillImage  image/jpeg
# 1  1052574205  StillImage  image/jpeg
#
#                                           identifier  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                    references title  description  source  \
# 0  https://www.inaturalist.org/photos/1290334   NaN          NaN     NaN
# 1  https://www.inaturalist.org/photos/1334856   NaN          NaN     NaN
#
#    audience               created      creator  contributor    publisher  \
# 0       NaN     2014-10-15T12:44Z     jenedson          NaN  iNaturalist
# 1       NaN  2014-11-09T10:51:54Z  Mella, Pete          NaN  iNaturalist
#
#                                              license rightsHolder
# 0     http://creativecommons.org/licenses/by-nc/4.0/     jenedson
# 1  http://creativecommons.org/licenses/by-nc-nd/4.0/  Mella, Pete

# %%
occurrence_df.head(2)
# Out:
#        gbifID accessRights bibliographicCitation language    license modified  \
# 0  3054616573          NaN                   NaN      NaN  CC_BY_4_0      NaN
# 1  3054616603          NaN                   NaN      NaN  CC_BY_4_0      NaN
#
#                                      publisher references rightsHolder type  \
# 0  Centre for Environmental Data and Recording        NaN        CEDaR  NaN
# 1  Centre for Environmental Data and Recording        NaN        CEDaR  NaN
#
#    ... publishedByGbifRegion level0Gid      level0Name level1Gid  \
# 0  ...                EUROPE       GBR  United Kingdom   GBR.2_1
# 1  ...                EUROPE       GBR  United Kingdom   GBR.2_1
#
#          level1Name  level2Gid               level2Name    level3Gid  \
# 0  Northern Ireland  GBR.2.5_1  Derry City and Strabane  GBR.2.5.2_1
# 1  Northern Ireland  GBR.2.9_1               Mid Ulster  GBR.2.9.3_1
#
#     level3Name  iucnRedListCategory
# 0     Strabane                   NE
# 1  Magherafelt                   NE
#
# [2 rows x 223 columns]

# %%
images_df = multimedia_df[multimedia_df['type'] == 'StillImage'][['gbifID', 'identifier']]

# %%
images_df
# Out:
#            gbifID                                         identifier
# 0      1038336887  https://inaturalist-open-data.s3.amazonaws.com...
# 1      1052574205  https://inaturalist-open-data.s3.amazonaws.com...
# 2      1098893451  https://inaturalist-open-data.s3.amazonaws.com...
# 3      1098916928  https://inaturalist-open-data.s3.amazonaws.com...
# 4      1098916928  https://inaturalist-open-data.s3.amazonaws.com...
# ...           ...                                                ...
# 86255   891123761  https://inaturalist-open-data.s3.amazonaws.com...
# 86256   891123761  https://inaturalist-open-data.s3.amazonaws.com...
# 86257   891123761  https://inaturalist-open-data.s3.amazonaws.com...
# 86258   891123761  https://inaturalist-open-data.s3.amazonaws.com...
# 86259   899978566  https://inaturalist-open-data.s3.amazonaws.com...
#
# [86260 rows x 2 columns]

# %%
# Merge occurrence data with the multimedia data based on gbifID
merged_df = pd.merge(occurrence_df, images_df, on='gbifID')

# Show the first few rows of the merged dataset
merged_df.head()
# Out:
#        gbifID accessRights bibliographicCitation language       license  \
# 0  3873668190          NaN                   NaN      NaN  CC_BY_NC_4_0
# 1  3902924915          NaN                   NaN      NaN       CC0_1_0
# 2  3415453004          NaN                   NaN      NaN  CC_BY_NC_4_0
# 3  4465704476          NaN                   NaN      NaN       CC0_1_0
# 4  4891738008          NaN                   NaN      NaN     CC_BY_4_0
#
#                modified        publisher  \
# 0  2022-07-12T20:11:33Z  iNaturalist.org
# 1  2022-08-25T16:37:55Z  iNaturalist.org
# 2  2024-03-13T17:30:30Z  iNaturalist.org
# 3  2024-04-19T12:13:04Z  iNaturalist.org
# 4  2024-06-13T09:14:57Z  iNaturalist.org
#
#                                           references    rightsHolder type  \
# 0  https://www.inaturalist.org/observations/12597...       Allie_Dav  NaN
# 1  https://www.inaturalist.org/observations/13228...   Sarah Adamson  NaN
# 2  https://www.inaturalist.org/observations/10059...          rmhall  NaN
# 3  https://www.inaturalist.org/observations/19311...  Jane Concannon  NaN
# 4  https://www.inaturalist.org/observations/15748...       Paul Cook  NaN
#
#    ... level0Gid      level0Name level1Gid level1Name   level2Gid  \
# 0  ...       GBR  United Kingdom   GBR.1_1    England  GBR.1.70_1
# 1  ...       GBR  United Kingdom   GBR.3_1   Scotland  GBR.3.12_1
# 2  ...       GBR  United Kingdom   GBR.1_1    England  GBR.1.63_1
# 3  ...       GBR  United Kingdom   GBR.1_1    England  GBR.1.88_1
# 4  ...       GBR  United Kingdom   GBR.1_1    England  GBR.1.36_1
#
#               level2Name      level3Gid             level3Name  \
# 0           Peterborough   GBR.1.70.1_1           Peterborough
# 1      City of Edinburgh   GBR.3.12.1_1              Edinburgh
# 2        North Yorkshire   GBR.1.63.5_1                Ryedale
# 3  South Gloucestershire   GBR.1.88.1_1  South Gloucestershire
# 4         Greater London  GBR.1.36.27_1   Richmond upon Thames
#
#   iucnRedListCategory                                         identifier
# 0                  NE  https://inaturalist-open-data.s3.amazonaws.com...
# 1                  NE  https://inaturalist-open-data.s3.amazonaws.com...
# 2                  NE  https://inaturalist-open-data.s3.amazonaws.com...
# 3                 NaN  https://inaturalist-open-data.s3.amazonaws.com...
# 4                  NE  https://inaturalist-open-data.s3.amazonaws.com...
#
# [5 rows x 224 columns]

# %%
# Select relevant columns
final_df = merged_df[[
    # 'gbifID',
    'scientificName',
    'species',
    # 'countryCode',
    # 'eventDate',
    # 'decimalLatitude',
    # 'decimalLongitude',
    'identifier'
    ]]


final_df = final_df.rename(columns={'identifier': 'url'})
# Show the dataset
final_df.head()
# Out:
#                                       scientificName  \
# 0  Subcoccinella vigintiquatuorpunctata (Linnaeus...
# 1           Coccinella septempunctata Linnaeus, 1758
# 2                   Harmonia axyridis (Pallas, 1773)
# 3                     Harmonia axyridis f. conspicua
# 4                  Stethorus pusillus (Herbst, 1797)
#
#                                 species  \
# 0  Subcoccinella vigintiquatuorpunctata
# 1             Coccinella septempunctata
# 2                     Harmonia axyridis
# 3                     Harmonia axyridis
# 4                    Stethorus pusillus
#
#                                                  url
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
# 2  https://inaturalist-open-data.s3.amazonaws.com...
# 3  https://inaturalist-open-data.s3.amazonaws.com...
# 4  https://inaturalist-open-data.s3.amazonaws.com...

# %%
# Remove urls from the data.nhm.ac.uk domain
print(f"Number of rows before removing data.nhm.ac.uk: {final_df.shape[0]}")
final_df = final_df[~final_df['url'].str.startswith('https://data.nhm.ac.uk/media')]
print(f"Number of rows after removing data.nhm.ac.uk: {final_df.shape[0]}")
# Out:
# Number of rows before removing data.nhm.ac.uk: 86260
# Number of rows after removing data.nhm.ac.uk: 85961

# %%
print(f'Shape before dropping nulls: {final_df.shape}')
final_df = final_df.dropna()
print(f'Shape after dropping nulls: {final_df.shape}')
# Out:
# Shape before dropping nulls: (85961, 3)
# Shape after dropping nulls: (85942, 3)

# %%
# Drop species with less than 1 image
species_counts = final_df['species'].value_counts()
species_counts = species_counts[species_counts > 10]
final_df = final_df[final_df['species'].isin(species_counts.index)]
print(f'Shape after dropping species with less than 10 images: {final_df.shape}')
# Out:
# Shape after dropping species with less than 10 images: (85883, 3)

# %%
# Convert species labels to integer labels
label_encoder = LabelEncoder()
final_df['label'] = label_encoder.fit_transform(final_df['species'])
labels = final_df['label']  # Updated labels for the dataset

# %%
train_df, test_df = train_test_split(
    final_df, test_size=0.2, random_state=42, stratify=final_df['species']
)

# %%
print(f'Train set: {len(train_df)} images')
print(f'Test set: {len(test_df)} images')
# Out:
# Train set: 68706 images
# Test set: 17177 images

# %%
train_df.to_csv('ladybird_train.csv', index=False)
test_df.to_csv('ladybird_test.csv', index=False)
final_df.to_csv('ladybird_full.csv', index=False)

# %% [markdown]
# # Small datasets

# %%
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
# Considering only 1/10th of the 50_000 images
reduction_factor = 10
np.random.seed(42)

# Choosing the random indices of small train set and small test set
idx_train = np.random.choice(len(train_df), round(len(train_df)/reduction_factor), replace=False)
idx_test = np.random.choice(len(test_df), round(len(test_df)/reduction_factor), replace=False)

# Collecting the two subsamples images_train_small and images_test_small from images_train and images_test
train_df_small = train_df.loc[idx_train].reset_index(drop=True)
test_df_small = test_df.loc[idx_test].reset_index(drop=True)


print("------------------ Before -----------------")
print(train_df.shape, test_df.shape)

print("")

print("--- After applying the reduction factor ---")
print(train_df_small.shape, test_df_small.shape)

print("")
print("-"*43)

unique, counts = np.unique(train_df_small['species'], return_counts=True)
dict(zip(unique, counts))
# Out:
# ------------------ Before -----------------
# (68706, 4) (17177, 4)
#
# --- After applying the reduction factor ---
# (6871, 4) (1718, 4)
#
# -------------------------------------------
# {'Adalia bipunctata': 340,
#  'Adalia decempunctata': 244,
#  'Anatis ocellata': 38,
#  'Anisosticta novemdecimpunctata': 18,
#  'Aphidecta obliterata': 26,
#  'Brumus quadripustulatus': 107,
#  'Calvia quatuordecimguttata': 159,
#  'Chilocorus bipustulatus': 5,
#  'Chilocorus renipustulatus': 51,
#  'Coccidula rufa': 5,
#  'Coccidula scutellata': 3,
#  'Coccinella hieroglyphica': 2,
#  'Coccinella magnifica': 1,
#  'Coccinella septempunctata': 1871,
#  'Coccinella undecimpunctata': 16,
#  'Halyzia sedecimguttata': 249,
#  'Harmonia axyridis': 2654,
#  'Harmonia quadripunctata': 34,
#  'Henosepilachna argus': 8,
#  'Hippodamia variegata': 27,
#  'Myrrha octodecimguttata': 5,
#  'Myzia oblongoguttata': 10,
#  'Nephus quadrimaculatus': 6,
#  'Propylaea quatuordecimpunctata': 391,
#  'Psyllobora vigintiduopunctata': 177,
#  'Rhyzobius chrysomeloides': 129,
#  'Rhyzobius forestieri': 5,
#  'Rhyzobius litura': 11,
#  'Rhyzobius lophanthae': 5,
#  'Scymnus auritus': 11,
#  'Scymnus interruptus': 7,
#  'Scymnus suturalis': 3,
#  'Stethorus pusillus': 35,
#  'Subcoccinella vigintiquatuorpunctata': 120,
#  'Tytthaspis sedecimpunctata': 98}

# %%
train_df_small.to_csv('ladybird_train_small.csv', index=False)
test_df_small.to_csv('ladybird_test_small.csv', index=False)
