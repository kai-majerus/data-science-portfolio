# %%
import requests
import pandas as pd
import os

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('FOOTBALL_DATA_KEY')
base_url = 'https://api.football-data.org/v4'
headers = {'X-Auth-Token': api_key}

# %%
def get_premier_league_matches(season: str) -> dict:
    url = f'{base_url}/competitions/PL/matches?season={season}&status=FINISHED'
    response = requests.get(url, headers=headers)
    data = response.json()
    return data['matches']

# %%
def calculate_home_points(row):
    if row['home_score'] > row['away_score']:
        return 3
    elif row['home_score'] == row['away_score']:
        return 1
    else:
        return 0


def calculate_away_points(row):
    if row['home_score'] < row['away_score']:
        return 3
    elif row['home_score'] == row['away_score']:
        return 1
    else:
        return 0


result_mapping = {'HOME_TEAM': 0, 'DRAW': 1, 'AWAY_TEAM': 2}

# %% [markdown]
# # 1 Season

# %%
matches = get_premier_league_matches(season='2023')
match_data = []
for match in matches:
    match_data.append({
        'date': match['utcDate'],
        'home_team': match['homeTeam']['shortName'],
        'away_team': match['awayTeam']['shortName'],
        'home_score': match['score']['fullTime']['home'],
        'away_score': match['score']['fullTime']['away'],
        'result': match['score']['winner'],
        'matchday': match['matchday']
    })

df = pd.DataFrame(match_data)
df = df.sort_values(by='date', ascending=True)
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#                          date      home_team   away_team  home_score  \
# 0   2023-08-11 19:00:00+00:00        Burnley    Man City           0
# 1   2023-08-12 12:00:00+00:00        Arsenal  Nottingham           2
# 2   2023-08-12 14:00:00+00:00    Bournemouth    West Ham           1
# 3   2023-08-12 14:00:00+00:00  Brighton Hove  Luton Town           4
# 4   2023-08-12 14:00:00+00:00        Everton      Fulham           0
# ..                        ...            ...         ...         ...
# 372 2024-05-19 15:00:00+00:00  Brighton Hove  Man United           0
# 371 2024-05-19 15:00:00+00:00      Brentford   Newcastle           2
# 370 2024-05-19 15:00:00+00:00        Arsenal     Everton           2
# 373 2024-05-19 15:00:00+00:00        Burnley  Nottingham           1
# 379 2024-05-19 15:00:00+00:00  Sheffield Utd   Tottenham           0
#
#      away_score     result  matchday
# 0             3  AWAY_TEAM         1
# 1             1  HOME_TEAM         1
# 2             1       DRAW         1
# 3             1  HOME_TEAM         1
# 4             1  AWAY_TEAM         1
# ..          ...        ...       ...
# 372           2  AWAY_TEAM        38
# 371           4  AWAY_TEAM        38
# 370           1  HOME_TEAM        38
# 373           2  AWAY_TEAM        38
# 379           3  AWAY_TEAM        38
#
# [380 rows x 7 columns]

# %%
df.head(2)
# Out:
#                        date home_team   away_team  home_score  away_score  \
# 0 2023-08-11 19:00:00+00:00   Burnley    Man City           0           3
# 1 2023-08-12 12:00:00+00:00   Arsenal  Nottingham           2           1
#
#       result  matchday
# 0  AWAY_TEAM         1
# 1  HOME_TEAM         1

# %%
df['home_points'] = df.apply(calculate_home_points, axis=1)
df['away_points'] = df.apply(calculate_away_points, axis=1)
df['result'] = df['result'].map(result_mapping)

# %%
df.head(2)
# Out:
#                        date home_team   away_team  home_score  away_score  \
# 0 2023-08-11 19:00:00+00:00   Burnley    Man City           0           3
# 1 2023-08-12 12:00:00+00:00   Arsenal  Nottingham           2           1
#
#    result  matchday  home_points  away_points
# 0       2         1            0            3
# 1       0         1            3            0

# %%
# Calculate rolling window stats
home_df = df[['date', 'home_team', 'home_score', 'away_score', 'home_points']].copy()
home_df.columns = ['date', 'team', 'goals_for', 'goals_against', 'points']

away_df = df[['date', 'away_team', 'away_score', 'home_score', 'away_points']].copy()
away_df.columns = ['date', 'team', 'goals_for', 'goals_against', 'points']

combined_df = pd.concat([home_df, away_df], ignore_index=True)

combined_df = combined_df.sort_values(by=['team', 'date']).reset_index(drop=True)

combined_df['form_last_5'] = combined_df.groupby('team')['points'].shift(
    1).rolling(window=5).sum().reset_index(0, drop=True)

combined_df['avg_goals_for_last_5'] = combined_df.groupby(
    'team')['goals_for'].shift(1).rolling(window=5).mean().reset_index(0, drop=True)

combined_df['avg_goals_against_last_5'] = combined_df.groupby(
    'team')['goals_against'].shift(1).rolling(window=5).mean().reset_index(0, drop=True)

combined_df
# Out:
#                          date           team  goals_for  goals_against  \
# 0   2023-08-12 12:00:00+00:00        Arsenal          2              1
# 1   2023-08-21 19:00:00+00:00        Arsenal          1              0
# 2   2023-08-26 14:00:00+00:00        Arsenal          2              2
# 3   2023-09-03 15:30:00+00:00        Arsenal          3              1
# 4   2023-09-17 15:30:00+00:00        Arsenal          1              0
# ..                        ...            ...        ...            ...
# 755 2024-04-24 18:45:00+00:00  Wolverhampton          0              1
# 756 2024-04-27 14:00:00+00:00  Wolverhampton          2              1
# 757 2024-05-04 16:30:00+00:00  Wolverhampton          1              5
# 758 2024-05-11 14:00:00+00:00  Wolverhampton          1              3
# 759 2024-05-19 15:00:00+00:00  Wolverhampton          0              2
#
#      points  form_last_5  avg_goals_for_last_5  avg_goals_against_last_5
# 0         3          NaN                   NaN                       NaN
# 1         3          NaN                   NaN                       NaN
# 2         1          NaN                   NaN                       NaN
# 3         3          NaN                   NaN                       NaN
# 4         3          NaN                   NaN                       NaN
# ..      ...          ...                   ...                       ...
# 755       0          2.0                   0.8                       1.8
# 756       3          2.0                   0.8                       1.6
# 757       0          4.0                   1.0                       1.6
# 758       0          4.0                   1.0                       2.2
# 759       0          3.0                   0.8                       2.4
#
# [760 rows x 8 columns]

# %%
home_stats = combined_df[['date', 'team', 'form_last_5', 'avg_goals_for_last_5', 'avg_goals_against_last_5']].copy()
away_stats = home_stats.copy()

# %%
# Merge home team stats back to the original DataFrame

df = pd.merge(df, home_stats, how='left', left_on=['home_team', 'date'], right_on=['team', 'date'])
df = df.rename(columns={
    'form_last_5': 'home_team_form_last_5',
    'avg_goals_for_last_5': 'home_team_avg_goals_for_last_5',
    'avg_goals_against_last_5': 'home_team_avg_goals_against_last_5'
})

# Merge away team stats back to the original DataFrame
df = pd.merge(df, away_stats, how='left', left_on=['away_team', 'date'], right_on=['team', 'date'])
df = df.rename(columns={
    'form_last_5': 'away_team_form_last_5',
    'avg_goals_for_last_5': 'away_team_avg_goals_for_last_5',
    'avg_goals_against_last_5': 'away_team_avg_goals_against_last_5'
})

# %%
df
# Out:
#                          date      home_team   away_team  home_score  \
# 0   2023-08-11 19:00:00+00:00        Burnley    Man City           0
# 1   2023-08-12 12:00:00+00:00        Arsenal  Nottingham           2
# 2   2023-08-12 14:00:00+00:00    Bournemouth    West Ham           1
# 3   2023-08-12 14:00:00+00:00  Brighton Hove  Luton Town           4
# 4   2023-08-12 14:00:00+00:00        Everton      Fulham           0
# ..                        ...            ...         ...         ...
# 375 2024-05-19 15:00:00+00:00  Brighton Hove  Man United           0
# 376 2024-05-19 15:00:00+00:00      Brentford   Newcastle           2
# 377 2024-05-19 15:00:00+00:00        Arsenal     Everton           2
# 378 2024-05-19 15:00:00+00:00        Burnley  Nottingham           1
# 379 2024-05-19 15:00:00+00:00  Sheffield Utd   Tottenham           0
#
#      away_score  result  matchday  home_points  away_points         team_x  \
# 0             3       2         1            0            3        Burnley
# 1             1       0         1            3            0        Arsenal
# 2             1       1         1            1            1    Bournemouth
# 3             1       0         1            3            0  Brighton Hove
# 4             1       2         1            0            3        Everton
# ..          ...     ...       ...          ...          ...            ...
# 375           2       2        38            0            3  Brighton Hove
# 376           4       2        38            0            3      Brentford
# 377           1       0        38            3            0        Arsenal
# 378           2       2        38            0            3        Burnley
# 379           3       2        38            0            3  Sheffield Utd
#
#      home_team_form_last_5  home_team_avg_goals_for_last_5  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
# ..                     ...                             ...
# 375                    4.0                             0.6
# 376                   10.0                             1.8
# 377                   15.0                             2.8
# 378                    5.0                             1.6
# 379                    0.0                             1.0
#
#      home_team_avg_goals_against_last_5      team_y  away_team_form_last_5  \
# 0                                   NaN    Man City                    NaN
# 1                                   NaN  Nottingham                    NaN
# 2                                   NaN    West Ham                    NaN
# 3                                   NaN  Luton Town                    NaN
# 4                                   NaN      Fulham                    NaN
# ..                                  ...         ...                    ...
# 375                                 2.0  Man United                    7.0
# 376                                 0.6   Newcastle                    7.0
# 377                                 0.4     Everton                   13.0
# 378                                 1.8  Nottingham                    4.0
# 379                                 3.4   Tottenham                    3.0
#
#      away_team_avg_goals_for_last_5  away_team_avg_goals_against_last_5
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# ..                              ...                                 ...
# 375                             1.6                                 2.0
# 376                             2.4                                 1.6
# 377                             1.4                                 0.2
# 378                             1.4                                 2.0
# 379                             1.2                                 2.4
#
# [380 rows x 17 columns]

# %%
# Check stats are good for Liverpool
df.loc[(df['home_team'] == 'Liverpool') | (df['away_team'] == 'Liverpool')]
# Out:
#                          date       home_team       away_team  home_score  \
# 8   2023-08-13 15:30:00+00:00         Chelsea       Liverpool           1
# 12  2023-08-19 14:00:00+00:00       Liverpool     Bournemouth           3
# 28  2023-08-27 15:30:00+00:00       Newcastle       Liverpool           1
# 37  2023-09-03 13:00:00+00:00       Liverpool     Aston Villa           3
# 39  2023-09-16 11:30:00+00:00   Wolverhampton       Liverpool           1
# 57  2023-09-24 13:00:00+00:00       Liverpool        West Ham           3
# 66  2023-09-30 16:30:00+00:00       Tottenham       Liverpool           2
# 76  2023-10-08 13:00:00+00:00   Brighton Hove       Liverpool           2
# 80  2023-10-21 11:30:00+00:00       Liverpool         Everton           2
# 98  2023-10-29 14:00:00+00:00       Liverpool      Nottingham           3
# 108 2023-11-05 16:30:00+00:00      Luton Town       Liverpool           1
# 117 2023-11-12 14:00:00+00:00       Liverpool       Brentford           3
# 120 2023-11-25 12:30:00+00:00        Man City       Liverpool           1
# 137 2023-12-03 14:00:00+00:00       Liverpool          Fulham           4
# 143 2023-12-06 19:30:00+00:00   Sheffield Utd       Liverpool           0
# 150 2023-12-09 12:30:00+00:00  Crystal Palace       Liverpool           1
# 168 2023-12-17 16:30:00+00:00       Liverpool      Man United           0
# 176 2023-12-23 17:30:00+00:00       Liverpool         Arsenal           1
# 181 2023-12-26 17:30:00+00:00         Burnley       Liverpool           0
# 196 2024-01-01 20:00:00+00:00       Liverpool       Newcastle           4
# 206 2024-01-21 16:30:00+00:00     Bournemouth       Liverpool           0
# 215 2024-01-31 20:15:00+00:00       Liverpool         Chelsea           4
# 226 2024-02-04 16:30:00+00:00         Arsenal       Liverpool           3
# 230 2024-02-10 15:00:00+00:00       Liverpool         Burnley           3
# 238 2024-02-17 12:30:00+00:00       Brentford       Liverpool           1
# 249 2024-02-21 19:30:00+00:00       Liverpool      Luton Town           4
# 260 2024-03-02 15:00:00+00:00      Nottingham       Liverpool           0
# 276 2024-03-10 15:45:00+00:00       Liverpool        Man City           1
# 291 2024-03-31 13:00:00+00:00       Liverpool   Brighton Hove           2
# 301 2024-04-04 18:30:00+00:00       Liverpool   Sheffield Utd           3
# 310 2024-04-07 14:30:00+00:00      Man United       Liverpool           2
# 319 2024-04-14 13:00:00+00:00       Liverpool  Crystal Palace           0
# 329 2024-04-21 15:30:00+00:00          Fulham       Liverpool           1
# 333 2024-04-24 19:00:00+00:00         Everton       Liverpool           2
# 336 2024-04-27 11:30:00+00:00        West Ham       Liverpool           2
# 355 2024-05-05 15:30:00+00:00       Liverpool       Tottenham           4
# 366 2024-05-13 19:00:00+00:00     Aston Villa       Liverpool           3
# 372 2024-05-19 15:00:00+00:00       Liverpool   Wolverhampton           2
#
#      away_score  result  matchday  home_points  away_points          team_x  \
# 8             1       1         1            1            1         Chelsea
# 12            1       0         2            3            0       Liverpool
# 28            2       2         3            0            3       Newcastle
# 37            0       0         4            3            0       Liverpool
# 39            3       2         5            0            3   Wolverhampton
# 57            1       0         6            3            0       Liverpool
# 66            1       0         7            3            0       Tottenham
# 76            2       1         8            1            1   Brighton Hove
# 80            0       0         9            3            0       Liverpool
# 98            0       0        10            3            0       Liverpool
# 108           1       1        11            1            1      Luton Town
# 117           0       0        12            3            0       Liverpool
# 120           1       1        13            1            1        Man City
# 137           3       0        14            3            0       Liverpool
# 143           2       2        15            0            3   Sheffield Utd
# 150           2       2        16            0            3  Crystal Palace
# 168           0       1        17            1            1       Liverpool
# 176           1       1        18            1            1       Liverpool
# 181           2       2        19            0            3         Burnley
# 196           2       0        20            3            0       Liverpool
# 206           4       2        21            0            3     Bournemouth
# 215           1       0        22            3            0       Liverpool
# 226           1       0        23            3            0         Arsenal
# 230           1       0        24            3            0       Liverpool
# 238           4       2        25            0            3       Brentford
# 249           1       0        26            3            0       Liverpool
# 260           1       2        27            0            3      Nottingham
# 276           1       1        28            1            1       Liverpool
# 291           1       0        30            3            0       Liverpool
# 301           1       0        31            3            0       Liverpool
# 310           2       1        32            1            1      Man United
# 319           1       2        33            0            3       Liverpool
# 329           3       2        34            0            3          Fulham
# 333           0       0        29            3            0         Everton
# 336           2       1        35            1            1        West Ham
# 355           2       0        36            3            0       Liverpool
# 366           3       1        37            1            1     Aston Villa
# 372           0       0        38            3            0       Liverpool
#
#      home_team_form_last_5  home_team_avg_goals_for_last_5  \
# 8                      NaN                             NaN
# 12                     NaN                             NaN
# 28                     NaN                             NaN
# 37                     NaN                             NaN
# 39                     NaN                             NaN
# 57                    13.0                             2.4
# 66                    13.0                             2.6
# 76                     9.0                             2.2
# 80                    10.0                             2.4
# 98                    10.0                             2.2
# 108                    4.0                             1.2
# 117                    8.0                             1.8
# 120                   10.0                             3.0
# 137                   11.0                             2.0
# 143                    4.0                             0.8
# 150                    4.0                             1.2
# 168                   13.0                             2.4
# 176                   11.0                             1.8
# 181                    7.0                             1.6
# 196                   11.0                             1.4
# 206                   12.0                             2.4
# 215                   11.0                             2.2
# 226                    7.0                             1.8
# 230                   12.0                             3.0
# 238                    6.0                             1.8
# 249                   12.0                             3.2
# 260                    4.0                             1.6
# 276                   12.0                             2.6
# 291                   13.0                             2.6
# 301                   13.0                             2.4
# 310                    4.0                             1.6
# 319                   11.0                             1.8
# 329                    7.0                             1.8
# 333                    7.0                             1.0
# 336                    4.0                             1.6
# 355                    5.0                             1.4
# 366                    8.0                             2.0
# 372                    8.0                             2.4
#
#      home_team_avg_goals_against_last_5          team_y  \
# 8                                   NaN       Liverpool
# 12                                  NaN     Bournemouth
# 28                                  NaN       Liverpool
# 37                                  NaN     Aston Villa
# 39                                  NaN       Liverpool
# 57                                  0.8        West Ham
# 66                                  1.0       Liverpool
# 76                                  2.4       Liverpool
# 80                                  1.2         Everton
# 98                                  1.2      Nottingham
# 108                                 1.8       Liverpool
# 117                                 1.0       Brentford
# 120                                 1.4       Liverpool
# 137                                 0.4          Fulham
# 143                                 3.0       Liverpool
# 150                                 1.6       Liverpool
# 168                                 1.0      Man United
# 176                                 1.0         Arsenal
# 181                                 0.8       Liverpool
# 196                                 0.4       Newcastle
# 206                                 1.0       Liverpool
# 215                                 0.6         Chelsea
# 226                                 1.2       Liverpool
# 230                                 1.2         Burnley
# 238                                 2.2       Liverpool
# 249                                 1.2      Luton Town
# 260                                 2.0       Liverpool
# 276                                 1.2        Man City
# 291                                 0.8   Brighton Hove
# 301                                 0.8   Sheffield Utd
# 310                                 2.0       Liverpool
# 319                                 1.0  Crystal Palace
# 329                                 1.4       Liverpool
# 333                                 1.8       Liverpool
# 336                                 2.6       Liverpool
# 355                                 1.6       Tottenham
# 366                                 1.4       Liverpool
# 372                                 2.0   Wolverhampton
#
#      away_team_form_last_5  away_team_avg_goals_for_last_5  \
# 8                      NaN                             NaN
# 12                     NaN                             NaN
# 28                     NaN                             NaN
# 37                     NaN                             NaN
# 39                     NaN                             NaN
# 57                    10.0                             2.0
# 66                    15.0                             2.8
# 76                    12.0                             2.4
# 80                     7.0                             1.8
# 98                     4.0                             0.8
# 108                   10.0                             2.2
# 117                   10.0                             2.0
# 120                   11.0                             2.2
# 137                    4.0                             1.0
# 143                   11.0                             2.4
# 150                   11.0                             2.2
# 168                    9.0                             1.2
# 176                   12.0                             1.8
# 181                   11.0                             1.8
# 196                    3.0                             1.0
# 206                   11.0                             1.8
# 215                   12.0                             1.8
# 226                   13.0                             3.0
# 230                    2.0                             1.2
# 238                   12.0                             3.2
# 249                    5.0                             2.2
# 260                   12.0                             3.2
# 276                   13.0                             1.6
# 291                    7.0                             1.6
# 301                    2.0                             1.0
# 310                   13.0                             2.2
# 319                    2.0                             1.0
# 329                    8.0                             1.6
# 333                   10.0                             2.0
# 336                    7.0                             1.6
# 355                    4.0                             1.2
# 366                    7.0                             1.8
# 372                    3.0                             0.8
#
#      away_team_avg_goals_against_last_5
# 8                                   NaN
# 12                                  NaN
# 28                                  NaN
# 37                                  NaN
# 39                                  NaN
# 57                                  1.4
# 66                                  0.8
# 76                                  1.0
# 80                                  1.2
# 98                                  1.2
# 108                                 1.0
# 117                                 1.0
# 120                                 0.6
# 137                                 1.8
# 143                                 1.0
# 150                                 1.0
# 168                                 1.0
# 176                                 1.0
# 181                                 1.0
# 196                                 2.2
# 206                                 0.8
# 215                                 1.0
# 226                                 0.8
# 230                                 2.2
# 238                                 1.4
# 249                                 2.0
# 260                                 1.4
# 276                                 0.4
# 291                                 1.2
# 301                                 3.4
# 310                                 0.8
# 319                                 2.0
# 329                                 1.2
# 333                                 1.2
# 336                                 1.4
# 355                                 2.2
# 366                                 1.6
# 372                                 2.4

# %%
# drop unused columns
df = df.drop(columns=['team_x', 'team_y', 'home_points', 'away_points', 'home_score', 'away_score'], axis=1)

# %%
df
# Out:
#                          date      home_team   away_team  result  matchday  \
# 0   2023-08-11 19:00:00+00:00        Burnley    Man City       2         1
# 1   2023-08-12 12:00:00+00:00        Arsenal  Nottingham       0         1
# 2   2023-08-12 14:00:00+00:00    Bournemouth    West Ham       1         1
# 3   2023-08-12 14:00:00+00:00  Brighton Hove  Luton Town       0         1
# 4   2023-08-12 14:00:00+00:00        Everton      Fulham       2         1
# ..                        ...            ...         ...     ...       ...
# 375 2024-05-19 15:00:00+00:00  Brighton Hove  Man United       2        38
# 376 2024-05-19 15:00:00+00:00      Brentford   Newcastle       2        38
# 377 2024-05-19 15:00:00+00:00        Arsenal     Everton       0        38
# 378 2024-05-19 15:00:00+00:00        Burnley  Nottingham       2        38
# 379 2024-05-19 15:00:00+00:00  Sheffield Utd   Tottenham       2        38
#
#      home_team_form_last_5  home_team_avg_goals_for_last_5  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
# ..                     ...                             ...
# 375                    4.0                             0.6
# 376                   10.0                             1.8
# 377                   15.0                             2.8
# 378                    5.0                             1.6
# 379                    0.0                             1.0
#
#      home_team_avg_goals_against_last_5  away_team_form_last_5  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ..                                  ...                    ...
# 375                                 2.0                    7.0
# 376                                 0.6                    7.0
# 377                                 0.4                   13.0
# 378                                 1.8                    4.0
# 379                                 3.4                    3.0
#
#      away_team_avg_goals_for_last_5  away_team_avg_goals_against_last_5
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
# ..                              ...                                 ...
# 375                             1.6                                 2.0
# 376                             2.4                                 1.6
# 377                             1.4                                 0.2
# 378                             1.4                                 2.0
# 379                             1.2                                 2.4
#
# [380 rows x 11 columns]

# %%
df = pd.get_dummies(df, columns=['home_team', 'away_team'], dtype=int)

# %%
df = df.dropna()
df
# Out:
#                          date  result  matchday  home_team_form_last_5  \
# 49  2023-09-23 14:00:00+00:00       1         6                    7.0
# 51  2023-09-23 14:00:00+00:00       0         6                   15.0
# 52  2023-09-23 16:30:00+00:00       2         6                    6.0
# 54  2023-09-24 13:00:00+00:00       1         6                   13.0
# 55  2023-09-24 13:00:00+00:00       0         6                   12.0
# ..                        ...     ...       ...                    ...
# 375 2024-05-19 15:00:00+00:00       2        38                    4.0
# 376 2024-05-19 15:00:00+00:00       2        38                   10.0
# 377 2024-05-19 15:00:00+00:00       0        38                   15.0
# 378 2024-05-19 15:00:00+00:00       2        38                    5.0
# 379 2024-05-19 15:00:00+00:00       2        38                    0.0
#
#      home_team_avg_goals_for_last_5  home_team_avg_goals_against_last_5  \
# 49                              1.2                                 1.4
# 51                              2.8                                 0.6
# 52                              1.6                                 1.2
# 54                              1.8                                 0.8
# 55                              3.0                                 1.4
# ..                              ...                                 ...
# 375                             0.6                                 2.0
# 376                             1.8                                 0.6
# 377                             2.8                                 0.4
# 378                             1.6                                 1.8
# 379                             1.0                                 3.4
#
#      away_team_form_last_5  away_team_avg_goals_for_last_5  \
# 49                     7.0                             1.0
# 51                     7.0                             1.4
# 52                     1.0                             0.4
# 54                    13.0                             2.6
# 55                     3.0                             0.8
# ..                     ...                             ...
# 375                    7.0                             1.6
# 376                    7.0                             2.4
# 377                   13.0                             1.4
# 378                    4.0                             1.4
# 379                    3.0                             1.2
#
#      away_team_avg_goals_against_last_5  home_team_Arsenal  ...  \
# 49                                  2.0                  0  ...
# 51                                  1.4                  0  ...
# 52                                  1.8                  0  ...
# 54                                  1.0                  1  ...
# 55                                  1.6                  0  ...
# ..                                  ...                ...  ...
# 375                                 2.0                  0  ...
# 376                                 1.6                  0  ...
# 377                                 0.2                  1  ...
# 378                                 2.0                  0  ...
# 379                                 2.4                  0  ...
#
#      away_team_Liverpool  away_team_Luton Town  away_team_Man City  \
# 49                     0                     0                   0
# 51                     0                     0                   0
# 52                     0                     0                   0
# 54                     0                     0                   0
# 55                     0                     0                   0
# ..                   ...                   ...                 ...
# 375                    0                     0                   0
# 376                    0                     0                   0
# 377                    0                     0                   0
# 378                    0                     0                   0
# 379                    0                     0                   0
#
#      away_team_Man United  away_team_Newcastle  away_team_Nottingham  \
# 49                      0                    0                     0
# 51                      0                    0                     1
# 52                      0                    0                     0
# 54                      0                    0                     0
# 55                      0                    0                     0
# ..                    ...                  ...                   ...
# 375                     1                    0                     0
# 376                     0                    1                     0
# 377                     0                    0                     0
# 378                     0                    0                     1
# 379                     0                    0                     0
#
#      away_team_Sheffield Utd  away_team_Tottenham  away_team_West Ham  \
# 49                         0                    0                   0
# 51                         0                    0                   0
# 52                         0                    0                   0
# 54                         0                    1                   0
# 55                         0                    0                   0
# ..                       ...                  ...                 ...
# 375                        0                    0                   0
# 376                        0                    0                   0
# 377                        0                    0                   0
# 378                        0                    0                   0
# 379                        0                    1                   0
#
#      away_team_Wolverhampton
# 49                         0
# 51                         0
# 52                         0
# 54                         0
# 55                         0
# ..                       ...
# 375                        0
# 376                        0
# 377                        0
# 378                        0
# 379                        0
#
# [329 rows x 49 columns]

# %% [markdown]
# # Multiple Seasons

# %%
seasons=['2022', '2023']
df = pd.DataFrame()
match_data = []
for season in seasons:
    matches = get_premier_league_matches(season=season)
    for match in matches:
        match_data.append({
            'date': match['utcDate'],
            'home_team': match['homeTeam']['shortName'],
            'away_team': match['awayTeam']['shortName'],
            'home_score': match['score']['fullTime']['home'],
            'away_score': match['score']['fullTime']['away'],
            'result': match['score']['winner'],
            'matchday': match['matchday']
        })

df = pd.DataFrame(match_data)

# %%
df
# Out:
#                      date       home_team      away_team  home_score  \
# 0    2022-08-05T19:00:00Z  Crystal Palace        Arsenal           0
# 1    2022-08-06T11:30:00Z          Fulham      Liverpool           2
# 2    2022-08-06T14:00:00Z       Tottenham    Southampton           4
# 3    2022-08-06T14:00:00Z       Newcastle     Nottingham           2
# 4    2022-08-06T14:00:00Z    Leeds United  Wolverhampton           2
# ..                    ...             ...            ...         ...
# 755  2024-05-19T15:00:00Z  Crystal Palace    Aston Villa           5
# 756  2024-05-19T15:00:00Z       Liverpool  Wolverhampton           2
# 757  2024-05-19T15:00:00Z      Luton Town         Fulham           2
# 758  2024-05-19T15:00:00Z        Man City       West Ham           3
# 759  2024-05-19T15:00:00Z   Sheffield Utd      Tottenham           0
#
#      away_score     result  matchday
# 0             2  AWAY_TEAM         1
# 1             2       DRAW         1
# 2             1  HOME_TEAM         1
# 3             0  HOME_TEAM         1
# 4             1  HOME_TEAM         1
# ..          ...        ...       ...
# 755           0  HOME_TEAM        38
# 756           0  HOME_TEAM        38
# 757           4  AWAY_TEAM        38
# 758           1  HOME_TEAM        38
# 759           3  AWAY_TEAM        38
#
# [760 rows x 7 columns]

# %%
df['home_points'] = df.apply(calculate_home_points, axis=1)
df['away_points'] = df.apply(calculate_away_points, axis=1)
df['result'] = df['result'].map(result_mapping)

home_df = df[['date', 'home_team', 'home_score', 'away_score', 'home_points']].copy()
home_df.columns = ['date', 'team', 'goals_for', 'goals_against', 'points']

away_df = df[['date', 'away_team', 'away_score', 'home_score', 'away_points']].copy()
away_df.columns = ['date', 'team', 'goals_for', 'goals_against', 'points']

combined_df = pd.concat([home_df, away_df], ignore_index=True)

combined_df = combined_df.sort_values(by=['team', 'date']).reset_index(drop=True)

combined_df['form_last_5'] = combined_df.groupby('team')['points'].shift(
    1).rolling(window=5).sum().reset_index(0, drop=True)

combined_df['avg_goals_for_last_5'] = combined_df.groupby(
    'team')['goals_for'].shift(1).rolling(window=5).mean().reset_index(0, drop=True)

combined_df['avg_goals_against_last_5'] = combined_df.groupby(
    'team')['goals_against'].shift(1).rolling(window=5).mean().reset_index(0, drop=True)

home_stats = combined_df[['date', 'team', 'form_last_5', 'avg_goals_for_last_5', 'avg_goals_against_last_5']].copy()
away_stats = home_stats.copy()

df = pd.merge(df, home_stats, how='left', left_on=['home_team', 'date'], right_on=['team', 'date'])
df = df.rename(columns={
    'form_last_5': 'home_team_form_last_5',
    'avg_goals_for_last_5': 'home_team_avg_goals_for_last_5',
    'avg_goals_against_last_5': 'home_team_avg_goals_against_last_5'
})

# Merge away team stats back to the original DataFrame
df = pd.merge(df, away_stats, how='left', left_on=['away_team', 'date'], right_on=['team', 'date'])
df = df.rename(columns={
    'form_last_5': 'away_team_form_last_5',
    'avg_goals_for_last_5': 'away_team_avg_goals_for_last_5',
    'avg_goals_against_last_5': 'away_team_avg_goals_against_last_5'
})

df = df.drop(columns=['team_x', 'team_y', 'home_points', 'away_points', 'home_score', 'away_score'], axis=1)

df = df.dropna()

# df = pd.get_dummies(df, columns=['home_team', 'away_team'], dtype=int)

# %%
df
# Out:
#                      date       home_team       away_team  result  matchday  \
# 50   2022-09-03T11:30:00Z         Everton       Liverpool       1         6
# 51   2022-09-03T14:00:00Z   Wolverhampton     Southampton       0         6
# 52   2022-09-03T14:00:00Z       Tottenham          Fulham       0         6
# 53   2022-09-03T14:00:00Z      Nottingham     Bournemouth       2         6
# 54   2022-09-03T14:00:00Z       Newcastle  Crystal Palace       1         6
# ..                    ...             ...             ...     ...       ...
# 755  2024-05-19T15:00:00Z  Crystal Palace     Aston Villa       0        38
# 756  2024-05-19T15:00:00Z       Liverpool   Wolverhampton       0        38
# 757  2024-05-19T15:00:00Z      Luton Town          Fulham       2        38
# 758  2024-05-19T15:00:00Z        Man City        West Ham       0        38
# 759  2024-05-19T15:00:00Z   Sheffield Utd       Tottenham       2        38
#
#      home_team_form_last_5  home_team_avg_goals_for_last_5  \
# 50                     3.0                             0.8
# 51                     3.0                             0.4
# 52                    11.0                             2.0
# 53                     4.0                             0.4
# 54                     6.0                             1.4
# ..                     ...                             ...
# 755                   13.0                             3.0
# 756                    8.0                             2.4
# 757                    1.0                             1.0
# 758                   15.0                             3.4
# 759                    0.0                             1.0
#
#      home_team_avg_goals_against_last_5  away_team_form_last_5  \
# 50                                  1.2                    8.0
# 51                                  0.8                    7.0
# 52                                  0.8                    8.0
# 53                                  2.2                    4.0
# 54                                  1.2                    5.0
# ..                                  ...                    ...
# 755                                 0.8                    8.0
# 756                                 2.0                    3.0
# 757                                 3.2                    5.0
# 758                                 0.2                    4.0
# 759                                 3.4                    3.0
#
#      away_team_avg_goals_for_last_5  away_team_avg_goals_against_last_5
# 50                              3.0                                 1.2
# 51                              1.4                                 1.8
# 52                              1.6                                 1.4
# 53                              0.4                                 3.2
# 54                              1.4                                 1.8
# ..                              ...                                 ...
# 755                             2.0                                 1.4
# 756                             0.8                                 2.4
# 757                             0.8                                 1.6
# 758                             1.4                                 3.0
# 759                             1.2                                 2.4
#
# [695 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'result', 'matchday',
#        'home_team_form_last_5', 'home_team_avg_goals_for_last_5',
#        'home_team_avg_goals_against_last_5', 'away_team_form_last_5',
#        'away_team_avg_goals_for_last_5', 'away_team_avg_goals_against_last_5'],
#       dtype='object')
